# %% [markdown]
# # F2 and F3 Level Models
#
# ## Exploring Changing Sentiment in Climate Articles: 2013 to 2023

# %% [markdown]
# #### This notebook builds F2 and F3 level models from the corpus.
#
# ### This is a notebook for calculatiing information, entropy, and perplexity of the series of climate literature texts described in other notebooks.
#
# #### Code adapated from notebooks authored by Rafael Alvarado(1). combination and adaptations credited to Caroline Kranefuss(1).
#
# (1) University of Virgina, 2026

# %% [markdown]
# ## Imports

# %%
# General imports
import pandas as pd 
import numpy as np 
import os
import sys

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Project-specific imports
import glob
from lxml import etree
from glob import glob
import re
import nltk
nltk_resources = [
    'tokenizers/punkt', 
    'averaged_perceptron_tagger_eng',
    'corpora/stopwords', 
    'help/tagsets'
]

for resource in nltk_resources:
    try:
        nltk.data.find(resource)
    except LookupError:
        nltk.download(resource)
        
        
# ----File Stitching----
# If not in repo home folder, cd back 
if os.path.basename(os.getcwd()) != "evolving_sentiment_climate":
    os.chdir('..')
# If a file is in /sources/, access it by telling the system to look at that path as well as current path
sys.path.append(os.path.join(os.getcwd(), '..', 'sources'))
source_dir = "sources"
source_files_paths = glob(f"{source_dir}/*.xml")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
# %%capture
# %run notebooks/eda.ipynb
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
TOKENS.head()
# Out:
#                                         pos pos_group token_str  term_str
# year mth_day doc_id sent_num token_num
# 2018 10-12   0      0        0           CC        CC   Neither   neither
#                              1          VBG        VB  reducing  reducing
#                              2           DT        DT       the       the
#                              3           NN        NN       use       use
#                              4           IN        IN        of        of

# %% [markdown]
# ## Exploring Length by Year

# %%
sns.relplot(LIB, kind='scatter', x='n_chaps', y='book_len', hue='author', height=10, aspect=1.5)

# Add labels
ax = plt.gca() # Get the current axes
for i, row in LIB.iterrows():
    x_pad = 0
    y_pad = LIB.book_len.max() // 100
    # Nudge these points vertically
    if i in [161, 21816, 158]:
        y_pad *= -2
    elif i in [4045]:
        y_pad *= 2.5
    ax.annotate(f"{row.title.title()} ({i})", xy=(row.n_chaps + x_pad, row.book_len + y_pad))

# Add the means of each feature as dotted lines
ax.axvline(LIB.n_chaps.mean(), c='lightgray', ls='--')    
ax.axhline(LIB.book_len.mean(), c='lightgray', ls='--')    

plt.title("Chapter Count vs Word Length by Author")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.relplot(LIB, kind='scatter', x='n_chaps', y='book_len', hue='author', height=10, aspect=1.5)
#       2
#       3 # Add labels
#       4 ax = plt.gca() # Get the current axes
#
# NameError: name 'LIB' is not defined
